# %%
import pandas as pd

table = pd.read_csv('../data/serie_a_league_table.csv')

# %%
table
# Out:
#           team  points  played  goalScored  goalConceded  goalDifference  \
# 0       Napoli      44      19          30            12              18
# 1     Atalanta      41      18          43            20              23
# 2        Inter      40      17          45            15              30
# 3        Lazio      35      19          33            27               6
# 4     Juventus      32      18          30            15              15
# 5   Fiorentina      32      18          31            18              13
# 6      Bologna      28      17          25            21               4
# 7        Milan      27      17          26            17               9
# 8      Udinese      25      19          23            28              -5
# 9         Roma      23      19          26            24               2
# 10      Torino      21      19          19            24              -5
# 11      Empoli      20      19          18            22              -4
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   team                  20 non-null     object
#  1   points                20 non-null     int64
#  2   played                20 non-null     int64
#  3   goalScored            20 non-null     int64
#  4   goalConceded          20 non-null     int64
#  5   goalDifference        20 non-null     int64
#  6   wins                  20 non-null     int64
#  7   draws                 20 non-null     int64
#  8   losses                20 non-null     int64
#  9   leaguePosition        20 non-null     int64
#  10  homeLeaguePosition_x  20 non-null     int64
#  11  awayLeaguePosition_x  20 non-null     int64
#  12  homePerformance       20 non-null     int64
#  13  awayPerformance       20 non-null     int64
#  14  recentForm            20 non-null     int64
# ...
